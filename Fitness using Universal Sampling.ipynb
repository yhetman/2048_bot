# %%
import math, copy
import numpy as np
from classNeuron import Neuron
from classNetwork import Network
import numpy as np
from classGame2048 import Game2048
import tkinter as tk
import time
import pickle
import concurrent.futures
from utils import *
from classGeneticLearner import GeneticLearner

fname = './universal_sampling/model_'
n_agents = 1000
generations_per_batch = 1
n_batches = 2000
total_generations = generations_per_batch * n_batches
print('Preparing to run ' + str(total_generations) +' generations...')

G = GeneticLearner(n_agents,[16,8,4],seed = 4)
for i in range(n_batches):
    print("Starting batch " + str(i))
    G.run_n_generations(generations_per_batch)
    gen_num = i * generations_per_batch
    save_model_state(G, fname + str(gen_num) + '.p')
    print("Model " + str(gen_num) + " Saved")
# Out:
# Preparing to run 2000 generations...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8a0119036229> in <module>()
#      19 print('Preparing to run ' + str(total_generations) +' generations...')
#      20
# ---> 21 G = GeneticLearner(n_agents,[16,8,4],seed = 4)
#      22 for i in range(n_batches):
#      23     print("Starting batch " + str(i))
#
# /mnt/DATA/Projects/UNIVERSITY/2048_bot/classGeneticLearner.py in __init__(self, n_agents, layer_sizes, seed)
#      55             self.n_to_keep = self.n_to_keep + 1
#      56             self.n_to_create = self.n_to_create - 1
# ---> 57         self.population_fitness_test()
#      58
#      59
#
# /mnt/DATA/Projects/UNIVERSITY/2048_bot/classGeneticLearner.py in population_fitness_test(self)
#      67
#      68     def population_fitness_test(self):
# ---> 69         self.agent_scores = [self.agents[i].play_game() for i in range(self.n_agents)]
#      70
#      71
#
# /mnt/DATA/Projects/UNIVERSITY/2048_bot/classGeneticLearner.py in <listcomp>(.0)
#      67
#      68     def population_fitness_test(self):
# ---> 69         self.agent_scores = [self.agents[i].play_game() for i in range(self.n_agents)]
#      70
#      71
#
# /mnt/DATA/Projects/UNIVERSITY/2048_bot/classAgent.py in play_game(self, gui_root)
#     118         while not game_over:
#     119             flat_state = np.copy(game.get_state(flat = True))
# --> 120             action = self.choose_action(flat_state)
#     121             game.swipe(action)
#     122             (game_over,win) = self.check_for_game_over(game, flat_state)
#
# /mnt/DATA/Projects/UNIVERSITY/2048_bot/classAgent.py in choose_action(self, input_state)
#      63
#      64     def choose_action(self, input_state):
# ---> 65         weighted_actions = self.evaluate_network(input_state)
#      66         max_idx = np.argmax(weighted_actions)
#      67         if max_idx == 0:
#
# /mnt/DATA/Projects/UNIVERSITY/2048_bot/classAgent.py in evaluate_network(self, input_state)
#      59         if input_state.shape[0] != self.nn_structure.get_number_of_inputs():
#      60             raise ValueError('Input is incorrect size for this Agent')
# ---> 61         return self.network.evaluate(input_state)
#      62
#      63
#
# /mnt/DATA/Projects/UNIVERSITY/2048_bot/classNetwork.py in evaluate(self, inputs)
#      28         intermediate_values = [inputs]
#      29         for i in range(1, self.n_layers + 1):
# ---> 30             intermediate_values.append(self.layers[i - 1].evaluate(intermediate_values[i - 1]))
#      31         return intermediate_values[-1]
#
# /mnt/DATA/Projects/UNIVERSITY/2048_bot/classLayer.py in evaluate(self, inputs)
#      35             return np.array([self.neurons[i].forward(inputs[i]) for i in range(self.n_neurons)])
#      36         else:
# ---> 37             return np.array([self.neurons[i].forward(inputs) for i in range(self.n_neurons)])
#      38
#      39
#
# /mnt/DATA/Projects/UNIVERSITY/2048_bot/classLayer.py in <listcomp>(.0)
#      35             return np.array([self.neurons[i].forward(inputs[i]) for i in range(self.n_neurons)])
#      36         else:
# ---> 37             return np.array([self.neurons[i].forward(inputs) for i in range(self.n_neurons)])
#      38
#      39
#
# /mnt/DATA/Projects/UNIVERSITY/2048_bot/classNeuron.py in forward(self, inputs)
#      23
#      24     def forward(self, inputs):
# ---> 25         self.fwd_sum = np.clip(np.sum(self.weights * inputs) + self.bias, -CLIP_LIMIT, CLIP_LIMIT)
#      26         return self.activation_fn()
#      27
#
# <__array_function__ internals> in clip(*args, **kwargs)
#
# /home/yhetman/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in clip(a, a_min, a_max, out, **kwargs)
#    2113
#    2114     """
# -> 2115     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#    2116
#    2117
#
# /home/yhetman/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# /home/yhetman/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _clip(a, min, max, out, casting, **kwargs)
#     132     if not _clip_dep_is_byte_swapped(a) and not _clip_dep_is_byte_swapped(out):
#     133         using_deprecated_nan = False
# --> 134         if _clip_dep_is_scalar_nan(min):
#     135             min = -float('inf')
#     136             using_deprecated_nan = True
#
# /home/yhetman/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _clip_dep_is_scalar_nan(a)
#      92     # guarded to protect circular imports
#      93     from numpy.core.fromnumeric import ndim
# ---> 94     if ndim(a) != 0:
#      95         return False
#      96     try:
#
# <__array_function__ internals> in ndim(*args, **kwargs)
#
# /home/yhetman/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in ndim(a)
#    3125
#    3126
# -> 3127 @array_function_dispatch(_ndim_dispatcher)
#    3128 def ndim(a):
#    3129     """
#
# KeyboardInterrupt:
