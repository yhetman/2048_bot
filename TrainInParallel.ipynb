# %%
import math, copy
import numpy as np
from classNeuron import Neuron
from classNetwork import Network
import numpy as np
from classGame2048 import Game2048
import tkinter as tk
import time
import pickle
import concurrent.futures
from utils import *
from classGeneticLearner import GeneticLearner

fname = './models2/model_'
n_agents = 1000
generations_per_batch = 1
n_batches = 2000
total_generations = generations_per_batch * n_batches
print('Preparing to run ' + str(total_generations) +' generations...')

G = GeneticLearner(n_agents,[16,8,4],seed = 4)
for i in range(n_batches):
    print("Starting batch " + str(i))
    G.run_n_generations(generations_per_batch)
    gen_num = i * generations_per_batch
    save_model_state(G, fname + str(gen_num) + '.p')
    print("Model " + str(gen_num) + " Saved")
# Out:
# Preparing to run 2000 generations...
# Starting batch 0
# Generation 0 - maximum: 436.0  median: 96.0 minimum: 24.0
# Model 0 Saved
# Starting batch 1
# Generation 0 - maximum: 768.0  median: 92.0 minimum: 24.0
# Model 1 Saved
# Starting batch 2
# Generation 0 - maximum: 748.0  median: 96.0 minimum: 24.0
# Model 2 Saved
# Starting batch 3
# Generation 0 - maximum: 1618.0  median: 98.0 minimum: 24.0
# Model 3 Saved
# Starting batch 4
# Generation 0 - maximum: 448.0  median: 98.0 minimum: 24.0
# Model 4 Saved
# Starting batch 5
# Generation 0 - maximum: 458.0  median: 100.0 minimum: 24.0
# Model 5 Saved
# Starting batch 6
# Generation 0 - maximum: 826.0  median: 100.0 minimum: 24.0
# Model 6 Saved
# Starting batch 7
# Generation 0 - maximum: 824.0  median: 100.0 minimum: 24.0
# Model 7 Saved
# Starting batch 8
# Generation 0 - maximum: 804.0  median: 100.0 minimum: 24.0
# Model 8 Saved
# Starting batch 9
# Generation 0 - maximum: 862.0  median: 104.0 minimum: 24.0
# Model 9 Saved
# Starting batch 10
# Generation 0 - maximum: 1502.0  median: 110.0 minimum: 24.0
# Model 10 Saved
# Starting batch 11
# Generation 0 - maximum: 1480.0  median: 112.0 minimum: 24.0
# Model 11 Saved
# Starting batch 12
# Generation 0 - maximum: 1560.0  median: 136.0 minimum: 24.0
# Model 12 Saved
# Starting batch 13
# Generation 0 - maximum: 1536.0  median: 210.0 minimum: 24.0
# Model 13 Saved
# Starting batch 14
# Generation 0 - maximum: 1508.0  median: 228.0 minimum: 24.0
# Model 14 Saved
# Starting batch 15
# Generation 0 - maximum: 1550.0  median: 236.0 minimum: 24.0
# Model 15 Saved
# Starting batch 16
# Generation 0 - maximum: 1496.0  median: 244.0 minimum: 24.0
# Model 16 Saved
# Starting batch 17
# Generation 0 - maximum: 1580.0  median: 242.0 minimum: 24.0
# Model 17 Saved
# Starting batch 18
# Generation 0 - maximum: 858.0  median: 252.0 minimum: 24.0
# Model 18 Saved
# Starting batch 19
# Generation 0 - maximum: 1514.0  median: 250.0 minimum: 24.0
# Model 19 Saved
# Starting batch 20
# Generation 0 - maximum: 1500.0  median: 252.0 minimum: 24.0
# Model 20 Saved
# Starting batch 21
# Generation 0 - maximum: 1494.0  median: 250.0 minimum: 24.0
# Model 21 Saved
# Starting batch 22
# Generation 0 - maximum: 1556.0  median: 256.0 minimum: 24.0
# Model 22 Saved
# Starting batch 23
# Generation 0 - maximum: 1522.0  median: 272.0 minimum: 24.0
# Model 23 Saved
# Starting batch 24
# Generation 0 - maximum: 1518.0  median: 252.0 minimum: 24.0
# Model 24 Saved
# Starting batch 25
# Generation 0 - maximum: 1522.0  median: 373.0 minimum: 24.0
# Model 25 Saved
# Starting batch 26
# Generation 0 - maximum: 1514.0  median: 264.0 minimum: 24.0
# Model 26 Saved
# Starting batch 27
# Generation 0 - maximum: 1530.0  median: 408.0 minimum: 24.0
# Model 27 Saved
# Starting batch 28
# Generation 0 - maximum: 1522.0  median: 262.0 minimum: 24.0
# Model 28 Saved
# Starting batch 29
# Generation 0 - maximum: 1560.0  median: 404.0 minimum: 24.0
# Model 29 Saved
# Starting batch 30
# Generation 0 - maximum: 1562.0  median: 404.0 minimum: 24.0
# Model 30 Saved
# Starting batch 31
# Generation 0 - maximum: 1534.0  median: 410.0 minimum: 24.0
# Model 31 Saved
# Starting batch 32
# Generation 0 - maximum: 1568.0  median: 410.0 minimum: 24.0
# Model 32 Saved
# Starting batch 33
# Generation 0 - maximum: 1516.0  median: 412.0 minimum: 24.0
# Model 33 Saved
# Starting batch 34
# Generation 0 - maximum: 1504.0  median: 412.0 minimum: 24.0
# Model 34 Saved
# Starting batch 35
# Generation 0 - maximum: 1522.0  median: 414.0 minimum: 26.0
# Model 35 Saved
# Starting batch 36
# Generation 0 - maximum: 1538.0  median: 411.0 minimum: 24.0
# Model 36 Saved
# Starting batch 37
# Generation 0 - maximum: 1546.0  median: 414.0 minimum: 24.0
# Model 37 Saved
# Starting batch 38
# Generation 0 - maximum: 1526.0  median: 412.0 minimum: 24.0
# Model 38 Saved
# Starting batch 39
# Generation 0 - maximum: 1508.0  median: 414.0 minimum: 24.0
# Model 39 Saved
# Starting batch 40
# Generation 0 - maximum: 1562.0  median: 414.0 minimum: 24.0
# Model 40 Saved
# Starting batch 41
# Generation 0 - maximum: 1530.0  median: 414.0 minimum: 24.0
# Model 41 Saved
# Starting batch 42
# Generation 0 - maximum: 1554.0  median: 418.0 minimum: 24.0
# Model 42 Saved
# Starting batch 43
# Generation 0 - maximum: 1598.0  median: 412.0 minimum: 24.0
# Model 43 Saved
# Starting batch 44
# Generation 0 - maximum: 1544.0  median: 418.0 minimum: 24.0
# Model 44 Saved
# Starting batch 45
# Generation 0 - maximum: 1524.0  median: 418.0 minimum: 24.0
# Model 45 Saved
# Starting batch 46
# Generation 0 - maximum: 1568.0  median: 419.0 minimum: 24.0
# Model 46 Saved
# Starting batch 47
# Generation 0 - maximum: 1514.0  median: 420.0 minimum: 24.0
# Model 47 Saved
# Starting batch 48
# Generation 0 - maximum: 1550.0  median: 414.0 minimum: 24.0
# Model 48 Saved
# Starting batch 49
# Generation 0 - maximum: 1538.0  median: 414.0 minimum: 24.0
# Model 49 Saved
# Starting batch 50
# Generation 0 - maximum: 1568.0  median: 420.0 minimum: 24.0
# Model 50 Saved
# Starting batch 51
# Generation 0 - maximum: 1552.0  median: 416.0 minimum: 24.0
# Model 51 Saved
# Starting batch 52
# Generation 0 - maximum: 1576.0  median: 418.0 minimum: 24.0
# Model 52 Saved
# Starting batch 53
# Generation 0 - maximum: 1576.0  median: 418.0 minimum: 24.0
# Model 53 Saved
# Starting batch 54
# Generation 0 - maximum: 1534.0  median: 416.0 minimum: 24.0
# Model 54 Saved
# Starting batch 55
# Generation 0 - maximum: 1550.0  median: 418.0 minimum: 24.0
# Model 55 Saved
# Starting batch 56
# Generation 0 - maximum: 1542.0  median: 416.0 minimum: 24.0
# Model 56 Saved
# Starting batch 57
# Generation 0 - maximum: 1568.0  median: 417.0 minimum: 24.0
# Model 57 Saved
# Starting batch 58
# Generation 0 - maximum: 1556.0  median: 418.0 minimum: 24.0
# Model 58 Saved
# Starting batch 59
# Generation 0 - maximum: 1568.0  median: 420.0 minimum: 24.0
# Model 59 Saved
# Starting batch 60
# Generation 0 - maximum: 1562.0  median: 420.0 minimum: 24.0
# Model 60 Saved
# Starting batch 61
# Generation 0 - maximum: 1566.0  median: 424.0 minimum: 26.0
# Model 61 Saved
# Starting batch 62
# Generation 0 - maximum: 1590.0  median: 424.0 minimum: 24.0
# Model 62 Saved
# Starting batch 63
# Generation 0 - maximum: 1554.0  median: 416.0 minimum: 24.0
# Model 63 Saved
# Starting batch 64
# Generation 0 - maximum: 1548.0  median: 422.0 minimum: 24.0
# Model 64 Saved
# Starting batch 65
# Generation 0 - maximum: 1546.0  median: 422.0 minimum: 24.0
# Model 65 Saved
# Starting batch 66
# Generation 0 - maximum: 1608.0  median: 424.0 minimum: 24.0
# Model 66 Saved
# Starting batch 67
# Generation 0 - maximum: 1610.0  median: 424.0 minimum: 24.0
# Model 67 Saved
# Starting batch 68
# Generation 0 - maximum: 1560.0  median: 424.0 minimum: 24.0
# Model 68 Saved
# Starting batch 69
# Generation 0 - maximum: 1556.0  median: 426.0 minimum: 24.0
# Model 69 Saved
# Starting batch 70
# Generation 0 - maximum: 1576.0  median: 424.0 minimum: 24.0
# Model 70 Saved
# Starting batch 71
# Generation 0 - maximum: 1558.0  median: 428.0 minimum: 24.0
# Model 71 Saved
# Starting batch 72
# Generation 0 - maximum: 1580.0  median: 426.0 minimum: 24.0
# Model 72 Saved
# Starting batch 73
# Generation 0 - maximum: 1592.0  median: 424.0 minimum: 24.0
# Model 73 Saved
# Starting batch 74
# Generation 0 - maximum: 1562.0  median: 426.0 minimum: 24.0
# Model 74 Saved
# Starting batch 75
# Generation 0 - maximum: 1590.0  median: 426.0 minimum: 24.0
# Model 75 Saved
# Starting batch 76
# Generation 0 - maximum: 1552.0  median: 428.0 minimum: 24.0
# Model 76 Saved
# Starting batch 77
# Generation 0 - maximum: 1578.0  median: 428.0 minimum: 24.0
# Model 77 Saved
# Starting batch 78
# Generation 0 - maximum: 1574.0  median: 426.0 minimum: 24.0
# Model 78 Saved
# Starting batch 79
# Generation 0 - maximum: 1562.0  median: 430.0 minimum: 24.0
# Model 79 Saved
# Starting batch 80
# Generation 0 - maximum: 2916.0  median: 430.0 minimum: 24.0
# Model 80 Saved
# Starting batch 81
# Generation 0 - maximum: 1590.0  median: 424.0 minimum: 24.0
# Model 81 Saved
# Starting batch 82
# Generation 0 - maximum: 1572.0  median: 432.0 minimum: 24.0
# Model 82 Saved
# Starting batch 83
# Generation 0 - maximum: 1568.0  median: 432.0 minimum: 24.0
# Model 83 Saved
# Starting batch 84
# Generation 0 - maximum: 1588.0  median: 430.0 minimum: 24.0
# Model 84 Saved
# Starting batch 85
# Generation 0 - maximum: 1570.0  median: 430.0 minimum: 24.0
# Model 85 Saved
# Starting batch 86
# Generation 0 - maximum: 1544.0  median: 424.0 minimum: 24.0
# Model 86 Saved
# Starting batch 87
# Generation 0 - maximum: 1580.0  median: 430.0 minimum: 24.0
# Model 87 Saved
# Starting batch 88
# Generation 0 - maximum: 1578.0  median: 428.0 minimum: 24.0
# Model 88 Saved
# Starting batch 89
# Generation 0 - maximum: 1618.0  median: 430.0 minimum: 24.0
# Model 89 Saved
# Starting batch 90
# Generation 0 - maximum: 1572.0  median: 430.0 minimum: 24.0
# Model 90 Saved
# Starting batch 91
# Generation 0 - maximum: 1562.0  median: 428.0 minimum: 24.0
# Model 91 Saved
# Starting batch 92
# Generation 0 - maximum: 1536.0  median: 427.0 minimum: 24.0
# Model 92 Saved
# Starting batch 93
# Generation 0 - maximum: 1590.0  median: 430.0 minimum: 24.0
# Model 93 Saved
# Starting batch 94
# Generation 0 - maximum: 1582.0  median: 430.0 minimum: 24.0
# Model 94 Saved
# Starting batch 95
# Generation 0 - maximum: 1572.0  median: 432.0 minimum: 24.0
# Model 95 Saved
# Starting batch 96
# Generation 0 - maximum: 1600.0  median: 434.0 minimum: 24.0
# Model 96 Saved
# Starting batch 97
# Generation 0 - maximum: 1590.0  median: 436.0 minimum: 24.0
# Model 97 Saved
# Starting batch 98
# Generation 0 - maximum: 1574.0  median: 434.0 minimum: 24.0
# Model 98 Saved
# Starting batch 99
# Generation 0 - maximum: 2950.0  median: 438.0 minimum: 24.0
# Model 99 Saved
# Starting batch 100
# Generation 0 - maximum: 1584.0  median: 430.0 minimum: 24.0
# Model 100 Saved
# Starting batch 101
# Generation 0 - maximum: 1578.0  median: 430.0 minimum: 24.0
# Model 101 Saved
# Starting batch 102
# Generation 0 - maximum: 1590.0  median: 432.0 minimum: 24.0
# Model 102 Saved
# Starting batch 103
# Generation 0 - maximum: 1582.0  median: 434.0 minimum: 24.0
# Model 103 Saved
# Starting batch 104
# Generation 0 - maximum: 1612.0  median: 432.0 minimum: 24.0
# Model 104 Saved
# Starting batch 105
# Generation 0 - maximum: 1572.0  median: 436.0 minimum: 24.0
# Model 105 Saved
# Starting batch 106
# Generation 0 - maximum: 1576.0  median: 436.0 minimum: 24.0
# Model 106 Saved
# Starting batch 107
# Generation 0 - maximum: 1572.0  median: 434.0 minimum: 24.0
# Model 107 Saved
# Starting batch 108
# Generation 0 - maximum: 1598.0  median: 440.0 minimum: 24.0
# Model 108 Saved
# Starting batch 109
# Generation 0 - maximum: 2914.0  median: 432.0 minimum: 24.0
# Model 109 Saved
# Starting batch 110
# Generation 0 - maximum: 1564.0  median: 434.0 minimum: 24.0
# Model 110 Saved
# Starting batch 111
# Generation 0 - maximum: 1554.0  median: 434.0 minimum: 24.0
# Model 111 Saved
# Starting batch 112
# Generation 0 - maximum: 2948.0  median: 438.0 minimum: 24.0
# Model 112 Saved
# Starting batch 113
# Generation 0 - maximum: 1586.0  median: 438.0 minimum: 24.0
# Model 113 Saved
# Starting batch 114
# Generation 0 - maximum: 1606.0  median: 436.0 minimum: 24.0
# Model 114 Saved
# Starting batch 115
# Generation 0 - maximum: 1576.0  median: 440.0 minimum: 24.0
# Model 115 Saved
# Starting batch 116
# Generation 0 - maximum: 1568.0  median: 437.0 minimum: 24.0
# Model 116 Saved
# Starting batch 117
# Generation 0 - maximum: 1594.0  median: 436.0 minimum: 24.0
# Model 117 Saved
# Starting batch 118
# Generation 0 - maximum: 1576.0  median: 442.0 minimum: 24.0
# Model 118 Saved
# Starting batch 119
# Generation 0 - maximum: 1574.0  median: 436.0 minimum: 24.0
# Model 119 Saved
# Starting batch 120
# Generation 0 - maximum: 1576.0  median: 438.0 minimum: 24.0
# Model 120 Saved
# Starting batch 121
# Generation 0 - maximum: 1592.0  median: 438.0 minimum: 24.0
# Model 121 Saved
# Starting batch 122
# Generation 0 - maximum: 1612.0  median: 440.0 minimum: 24.0
# Model 122 Saved
# Starting batch 123
# Generation 0 - maximum: 1594.0  median: 440.0 minimum: 24.0
# Model 123 Saved
# Starting batch 124
# Generation 0 - maximum: 1578.0  median: 436.0 minimum: 24.0
# Model 124 Saved
# Starting batch 125
# Generation 0 - maximum: 2956.0  median: 438.0 minimum: 24.0
# Model 125 Saved
# Starting batch 126
# Generation 0 - maximum: 1560.0  median: 436.0 minimum: 24.0
# Model 126 Saved
# Starting batch 127
# Generation 0 - maximum: 1588.0  median: 438.0 minimum: 24.0
# Model 127 Saved
# Starting batch 128
# Generation 0 - maximum: 1582.0  median: 444.0 minimum: 24.0
# Model 128 Saved
# Starting batch 129
# Generation 0 - maximum: 1610.0  median: 438.0 minimum: 24.0
# Model 129 Saved
# Starting batch 130
# Generation 0 - maximum: 1582.0  median: 436.0 minimum: 24.0
# Model 130 Saved
# Starting batch 131
# Generation 0 - maximum: 1566.0  median: 444.0 minimum: 24.0
# Model 131 Saved
# Starting batch 132
# Generation 0 - maximum: 1596.0  median: 440.0 minimum: 24.0
# Model 132 Saved
# Starting batch 133
# Generation 0 - maximum: 1568.0  median: 444.0 minimum: 24.0
# Model 133 Saved
# Starting batch 134
# Generation 0 - maximum: 2922.0  median: 440.0 minimum: 24.0
# Model 134 Saved
# Starting batch 135
# Generation 0 - maximum: 2908.0  median: 438.0 minimum: 24.0
# Model 135 Saved
# Starting batch 136
# Generation 0 - maximum: 1598.0  median: 441.0 minimum: 24.0
# Model 136 Saved
# Starting batch 137
# Generation 0 - maximum: 1596.0  median: 440.0 minimum: 24.0
# Model 137 Saved
# Starting batch 138
# Generation 0 - maximum: 1586.0  median: 440.0 minimum: 24.0
# Model 138 Saved
# Starting batch 139
# Generation 0 - maximum: 1582.0  median: 438.0 minimum: 24.0
# Model 139 Saved
# Starting batch 140
# Generation 0 - maximum: 2918.0  median: 442.0 minimum: 24.0
# Model 140 Saved
# Starting batch 141
# Generation 0 - maximum: 2932.0  median: 438.0 minimum: 24.0
# Model 141 Saved
# Starting batch 142
# Generation 0 - maximum: 1588.0  median: 439.0 minimum: 24.0
# Model 142 Saved
# Starting batch 143
# Generation 0 - maximum: 1592.0  median: 440.0 minimum: 24.0
# Model 143 Saved
# Starting batch 144
# Generation 0 - maximum: 1596.0  median: 440.0 minimum: 24.0
# Model 144 Saved
# Starting batch 145
# Generation 0 - maximum: 1586.0  median: 438.0 minimum: 24.0
# Model 145 Saved
# Starting batch 146
# Generation 0 - maximum: 2920.0  median: 440.0 minimum: 24.0
# Model 146 Saved
# Starting batch 147
# Generation 0 - maximum: 1586.0  median: 440.0 minimum: 24.0
# Model 147 Saved
# Starting batch 148
# Generation 0 - maximum: 1588.0  median: 442.0 minimum: 24.0
# Model 148 Saved
# Starting batch 149
# Generation 0 - maximum: 1616.0  median: 444.0 minimum: 24.0
# Model 149 Saved
# Starting batch 150
# Generation 0 - maximum: 1582.0  median: 438.0 minimum: 24.0
# Model 150 Saved
# Starting batch 151
# Generation 0 - maximum: 1580.0  median: 440.0 minimum: 24.0
# Model 151 Saved
# Starting batch 152
# Generation 0 - maximum: 2882.0  median: 436.0 minimum: 24.0
# Model 152 Saved
# Starting batch 153
# Generation 0 - maximum: 1578.0  median: 444.0 minimum: 24.0
# Model 153 Saved
# Starting batch 154
# Generation 0 - maximum: 1588.0  median: 436.0 minimum: 24.0
# Model 154 Saved
# Starting batch 155
# Generation 0 - maximum: 1590.0  median: 440.0 minimum: 24.0
# Model 155 Saved
# Starting batch 156
# Generation 0 - maximum: 1612.0  median: 438.0 minimum: 24.0
# Model 156 Saved
# Starting batch 157
# Generation 0 - maximum: 1582.0  median: 440.0 minimum: 24.0
# Model 157 Saved
# Starting batch 158
# Generation 0 - maximum: 1578.0  median: 438.0 minimum: 24.0
# Model 158 Saved
# Starting batch 159
# Generation 0 - maximum: 1622.0  median: 440.0 minimum: 24.0
# Model 159 Saved
# Starting batch 160
# Generation 0 - maximum: 1596.0  median: 440.0 minimum: 24.0
# Model 160 Saved
# Starting batch 161
# Generation 0 - maximum: 1592.0  median: 443.0 minimum: 24.0
# Model 161 Saved
# Starting batch 162
